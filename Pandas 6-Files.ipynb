# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_table('ex1.csv')

# %%
df
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello
# 1   5,6,7,8,world
# 2  9,10,11,12,foo

# %%
df.columns
# Out:
# Index(['a,b,c,d,message'], dtype='object')

# %%
#csv file.

# %%
#to remove commas for columns

# %%
df2=pd.read_table('ex1.csv',sep=',')

# %%
df2
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df2.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'message'], dtype='object')

# %%
#to avoaid commas we use read_csv

# %%
df3=pd.read_csv('ex1.csv')

# %%
df3
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
#to add header to rows

# %%
df4=pd.read_csv('ex1.csv',header=None)

# %%
df4
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
#to read xlsx file

# %%
df5=pd.read_excel('ex1.xlsx')

# %%
df5
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
df6=pd.read_excel('ex1.xlsx',header=None)

# %%
df6
# Out:
#      0  1   2   3   4        5
# 0  NaN  a   b   c   d  message
# 1  0.0  1   2   3   4    hello
# 2  1.0  5   6   7   8    world
# 3  2.0  9  10  11  12      foo

# %%
#date range function

# %%
dates=pd.date_range('5/25/2020',periods=10)

# %%
dates
# Out:
# DatetimeIndex(['2020-05-25', '2020-05-26', '2020-05-27', '2020-05-28',
#                '2020-05-29', '2020-05-30', '2020-05-31', '2020-06-01',
#                '2020-06-02', '2020-06-03'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts=pd.Series(np.arange(10),index=dates)

# %%
ts
# Out:
# 2020-05-25    0
# 2020-05-26    1
# 2020-05-27    2
# 2020-05-28    3
# 2020-05-29    4
# 2020-05-30    5
# 2020-05-31    6
# 2020-06-01    7
# 2020-06-02    8
# 2020-06-03    9
# Freq: D, dtype: int64

# %%
#to convert ts to a csv file

# %%
ts.to_csv('extimeseries.csv')

# %%
ts1=pd.read_csv('extimeseries.csv')

# %%
ts1
# Out:
#    Unnamed: 0  0
# 0  2020-05-25  0
# 1  2020-05-26  1
# 2  2020-05-27  2
# 3  2020-05-28  3
# 4  2020-05-29  4
# 5  2020-05-30  5
# 6  2020-05-31  6
# 7  2020-06-01  7
# 8  2020-06-02  8
# 9  2020-06-03  9

# %%
ts1.head()
# Out:
#    Unnamed: 0  0
# 0  2020-05-25  0
# 1  2020-05-26  1
# 2  2020-05-27  2
# 3  2020-05-28  3
# 4  2020-05-29  4

# %%
ts1.to_html('exsample.html')

# %%
#converting to html file.

# %%
tables=pd.read_html('bank.html')

# %%
len(tables)
# Out:
# 1

# %%
tables
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
t1=tables[0]

# %%
t1.head(50)
# Out:
#                                             Bank Name             City  ST  \
# 0                                         Allied Bank         Mulberry  AR
# 1                        The Woodbury Banking Company         Woodbury  GA
# 2                              First CornerStone Bank  King of Prussia  PA
# 3                                  Trust Company Bank          Memphis  TN
# 4                          North Milwaukee State Bank        Milwaukee  WI
# 5                              Hometown National Bank         Longview  WA
# 6                                 The Bank of Georgia   Peachtree City  GA
# 7                                        Premier Bank           Denver  CO
# 8                                      Edgebrook Bank          Chicago  IL
# 9                              Doral Bank  En Espanol         San Juan  PR
# 10                  Capitol City Bank & Trust Company          Atlanta  GA
# ...

# %%
t1['Bank Name'].head(50)
# Out:
# 0                                           Allied Bank
# 1                          The Woodbury Banking Company
# 2                                First CornerStone Bank
# 3                                    Trust Company Bank
# 4                            North Milwaukee State Bank
# 5                                Hometown National Bank
# 6                                   The Bank of Georgia
# 7                                          Premier Bank
# 8                                        Edgebrook Bank
# 9                                Doral Bank  En Espanol
# 10                    Capitol City Bank & Trust Company
# 11                              Highland Community Bank
# 12                     First National Bank of Crestview
# 13                                   Northern Star Bank
# 14               Frontier Bank, FSB D/B/A El Paseo Bank
# 15                The National Republic Bank of Chicago
# 16                                       NBRS Financial
# ...

# %%
t1.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
t1['Updated Date']
# Out:
# 0      November 17, 2016
# 1      November 17, 2016
# 2      September 6, 2016
# 3      September 6, 2016
# 4          June 16, 2016
#              ...
# 542      August 19, 2014
# 543    November 18, 2002
# 544    February 18, 2003
# 545       March 17, 2005
# 546       March 17, 2005
# Name: Updated Date, Length: 547, dtype: object

# %% [markdown]
# # Converting data into Date time format.

# %%
t2=pd.to_datetime(t1['Updated Date'])

# %%
t2
# Out:
# 0     2016-11-17
# 1     2016-11-17
# 2     2016-09-06
# 3     2016-09-06
# 4     2016-06-16
#          ...
# 542   2014-08-19
# 543   2002-11-18
# 544   2003-02-18
# 545   2005-03-17
# 546   2005-03-17
# Name: Updated Date, Length: 547, dtype: datetime64[ns]

# %%
#converts the data into DateTime format

# %%
t2.dt.year.value_counts()
# Out:
# 2012    227
# 2014    109
# 2016     91
# 2015     66
# 2013     36
# 2008      6
# 2005      5
# 2004      2
# 2003      2
# 2010      1
# 2006      1
# 2002      1
# Name: Updated Date, dtype: int64

# %%
#to calculate the count of values in each year.

# %%
chucker=pd.read_csv('ex6.csv')

# %%
chucker
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
chucker.head()
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
chucker1=pd.read_csv('ex6.csv',chunksize=10)

# %%
chucker1

# %% [markdown]
# #chuck size is a integer to return text file reader object for iteration

# %%
#chucker1.head()

# %% [markdown]
# #throws an Attribute error as TextFile Reader doesnt have an attribute haed.

# %%
tot=pd.Series([])
# Out:
# /Users/saisandeeptatineni/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
for piece in chucker1:
    tot=tot.add(piece['key'].value_counts(),fill_value=0)
    tot=tot.sort_values(ascending=True)

# %%
tot
# Out:
# 1    146.0
# 9    150.0
# 0    151.0
# 2    152.0
# 5    157.0
# 3    162.0
# 8    162.0
# 7    164.0
# 6    166.0
# 4    171.0
# C    286.0
# Z    288.0
# B    302.0
# T    304.0
# W    305.0
# N    306.0
# S    308.0
# G    308.0
# Y    314.0
# R    318.0
# A    320.0
# D    320.0
# P    324.0
# U    326.0
# I    327.0
# V    328.0
# H    330.0
# K    334.0
# F    335.0
# J    337.0
# M    338.0
# Q    340.0
# O    343.0
# L    346.0
# X    364.0
# E    368.0
# dtype: float64
